# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
s = pd.Series([1,2,3,4,5], index = ["a","b","c","d","e"])

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
df = pd.DataFrame({"names" : ["mohit","snehal","pranav","pradipta",],"marks" : [90,99.9,69,99.9]})

# %%
df
# Out:
#       names  marks
# 0     mohit   90.0
# 1    snehal   99.9
# 2    pranav   69.0
# 3  pradipta   99.9

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 50980                          Quick ratio  Financial ratios    52
# 50981  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
df["Year"]
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2013
# 50981    2013
# 50982    2013
# 50983    2013
# 50984    2013
# Name: Year, Length: 50985, dtype: int64

# %%
type(df["Year"])
# Out:
# pandas.core.series.Series

# %%
df[["Year","Industry_aggregation_NZSIOC"]]
# Out:
#        Year Industry_aggregation_NZSIOC
# 0      2023                     Level 1
# 1      2023                     Level 1
# 2      2023                     Level 1
# 3      2023                     Level 1
# 4      2023                     Level 1
# ...     ...                         ...
# 50980  2013                     Level 3
# 50981  2013                     Level 3
# 50982  2013                     Level 3
# 50983  2013                     Level 3
# 50984  2013                     Level 3
#
# [50985 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Year                                                                        2023
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H01
# Variable_name                                                       Total income
# Variable_category                                          Financial performance
# Value                                                                     930995
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.dropna()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df2 = pd.read_csv("data.csv")

# %%
df2.fillna(0)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.rename(columns = {"Industry_aggregation_NZSIOC":"Industry level's"})
# Out:
#        Year Industry level's Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0      2023          Level 1                99999              All industries
# 1      2023          Level 1                99999              All industries
# 2      2023          Level 1                99999              All industries
# 3      2023          Level 1                99999              All industries
# 4      2023          Level 1                99999              All industries
# ...     ...              ...                  ...                         ...
# 50980  2013          Level 3                 ZZ11  Food product manufacturing
# 50981  2013          Level 3                 ZZ11  Food product manufacturing
# 50982  2013          Level 3                 ZZ11  Food product manufacturing
# 50983  2013          Level 3                 ZZ11  Food product manufacturing
# 50984  2013          Level 3                 ZZ11  Food product manufacturing
#
# ...

# %%
df.rename(columns = {"Industry_code_NZSIOC":"Industry code"})
# Out:
#        Year Industry_aggregation_NZSIOC Industry code  \
# 0      2023                     Level 1         99999
# 1      2023                     Level 1         99999
# 2      2023                     Level 1         99999
# 3      2023                     Level 1         99999
# 4      2023                     Level 1         99999
# ...     ...                         ...           ...
# 50980  2013                     Level 3          ZZ11
# 50981  2013                     Level 3          ZZ11
# 50982  2013                     Level 3          ZZ11
# 50983  2013                     Level 3          ZZ11
# 50984  2013                     Level 3          ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.rename(columns = {"Industry_aggregation_NZSIOC":"Industry level's"}, inplace = True)

# %%
df
# Out:
#        Year Industry level's Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0      2023          Level 1                99999              All industries
# 1      2023          Level 1                99999              All industries
# 2      2023          Level 1                99999              All industries
# 3      2023          Level 1                99999              All industries
# 4      2023          Level 1                99999              All industries
# ...     ...              ...                  ...                         ...
# 50980  2013          Level 3                 ZZ11  Food product manufacturing
# 50981  2013          Level 3                 ZZ11  Food product manufacturing
# 50982  2013          Level 3                 ZZ11  Food product manufacturing
# 50983  2013          Level 3                 ZZ11  Food product manufacturing
# 50984  2013          Level 3                 ZZ11  Food product manufacturing
#
# ...

# %%
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    50985 non-null  int64
#  1   Industry level's        50985 non-null  object
#  2   Industry_code_NZSIOC    50985 non-null  object
#  3   Industry_name_NZSIOC    50985 non-null  object
#  4   Units                   50985 non-null  object
#  5   Variable_code           50985 non-null  object
#  6   Variable_name           50985 non-null  object
#  7   Variable_category       50985 non-null  object
#  8   Value                   50985 non-null  object
#  9   Industry_code_ANZSIC06  50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
df['Year'] = df['Year'].astype(float)

# %%
df
# Out:
#          Year Industry level's Industry_code_NZSIOC  \
# 0      2023.0          Level 1                99999
# 1      2023.0          Level 1                99999
# 2      2023.0          Level 1                99999
# 3      2023.0          Level 1                99999
# 4      2023.0          Level 1                99999
# ...       ...              ...                  ...
# 50980  2013.0          Level 3                 ZZ11
# 50981  2013.0          Level 3                 ZZ11
# 50982  2013.0          Level 3                 ZZ11
# 50983  2013.0          Level 3                 ZZ11
# 50984  2013.0          Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
df['Year'] = df['Year'].astype(int)

# %%
df
# Out:
#        Year Industry level's Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0      2023          Level 1                99999              All industries
# 1      2023          Level 1                99999              All industries
# 2      2023          Level 1                99999              All industries
# 3      2023          Level 1                99999              All industries
# 4      2023          Level 1                99999              All industries
# ...     ...              ...                  ...                         ...
# 50980  2013          Level 3                 ZZ11  Food product manufacturing
# 50981  2013          Level 3                 ZZ11  Food product manufacturing
# 50982  2013          Level 3                 ZZ11  Food product manufacturing
# 50983  2013          Level 3                 ZZ11  Food product manufacturing
# 50984  2013          Level 3                 ZZ11  Food product manufacturing
#
# ...

# %%
len(df)
# Out:
# 50985

# %%
df["zeroes"] = [0 for i in range(len(df))]

# %%
df
# Out:
#        Year Industry level's Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0      2023          Level 1                99999              All industries
# 1      2023          Level 1                99999              All industries
# 2      2023          Level 1                99999              All industries
# 3      2023          Level 1                99999              All industries
# 4      2023          Level 1                99999              All industries
# ...     ...              ...                  ...                         ...
# 50980  2013          Level 3                 ZZ11  Food product manufacturing
# 50981  2013          Level 3                 ZZ11  Food product manufacturing
# 50982  2013          Level 3                 ZZ11  Food product manufacturing
# 50983  2013          Level 3                 ZZ11  Food product manufacturing
# 50984  2013          Level 3                 ZZ11  Food product manufacturing
#
# ...

# %%
def fx(a):
    return a+a+2
df["zeroes + 1"] = df["zeroes"] .apply(fx)

# %%
df
# Out:
#        Year Industry level's Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0      2023          Level 1                99999              All industries
# 1      2023          Level 1                99999              All industries
# 2      2023          Level 1                99999              All industries
# 3      2023          Level 1                99999              All industries
# 4      2023          Level 1                99999              All industries
# ...     ...              ...                  ...                         ...
# 50980  2013          Level 3                 ZZ11  Food product manufacturing
# 50981  2013          Level 3                 ZZ11  Food product manufacturing
# 50982  2013          Level 3                 ZZ11  Food product manufacturing
# 50983  2013          Level 3                 ZZ11  Food product manufacturing
# 50984  2013          Level 3                 ZZ11  Food product manufacturing
#
# ...

# %%
df.to_csv("data02.csv", index=False)

# %%
df1 = pd.DataFrame({
    "name": ["mohit","rohit","snehal","pranav","shubham","onu"],
    "marks": [100,20,99,69,78,23],
})

# %%
df1
# Out:
#       name  marks
# 0    mohit    100
# 1    rohit     20
# 2   snehal     99
# 3   pranav     69
# 4  shubham     78
# 5      onu     23

# %%
df2 = pd.DataFrame({
    "name": ["mohit","rohit","snehal","pranav","shubham","onu"],
    "rollno": [24,20,61,23,69,63],
})

# %%
df2
# Out:
#       name  rollno
# 0    mohit      24
# 1    rohit      20
# 2   snehal      61
# 3   pranav      23
# 4  shubham      69
# 5      onu      63

# %%
pd.concat([df1,df2])
# Out:
#       name  marks  rollno
# 0    mohit  100.0     NaN
# 1    rohit   20.0     NaN
# 2   snehal   99.0     NaN
# 3   pranav   69.0     NaN
# 4  shubham   78.0     NaN
# 5      onu   23.0     NaN
# 0    mohit    NaN    24.0
# 1    rohit    NaN    20.0
# 2   snehal    NaN    61.0
# 3   pranav    NaN    23.0
# 4  shubham    NaN    69.0
# 5      onu    NaN    63.0

# %%
pd.merge(df1,df2,on= "name")
# Out:
#       name  marks  rollno
# 0    mohit    100      24
# 1    rohit     20      20
# 2   snehal     99      61
# 3   pranav     69      23
# 4  shubham     78      69
# 5      onu     23      63
