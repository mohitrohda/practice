# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"names" : ["mohit","snehal","pranav","pradipta","bhupesh","onu","elon"],"incomes" : [4000,5000,6000,7000,7500,8000,10000000]})

# %%
df
# Out:
#       names   incomes
# 0     mohit      4000
# 1    snehal      5000
# 2    pranav      6000
# 3  pradipta      7000
# 4   bhupesh      7500
# 5       onu      8000
# 6      elon  10000000

# %%
df.describe()
# Out:
#             incomes
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.incomes.quantile(0.25)
# Out:
# np.float64(5500.0)

# %%
df.incomes.quantile(0.25, interpolation = "lower")
# Out:
# np.int64(5000)

# %%
df.incomes.quantile(0.25, interpolation = "higher")
# Out:
# np.int64(6000)

# %%
df.incomes.quantile(0)
# Out:
# np.float64(4000.0)

# %%
df.incomes.quantile(1)
# Out:
# np.float64(10000000.0)

# %%
percentile_99 = df.incomes.quantile(0.99)
percentile_99
# Out:
# np.float64(9400479.999999994)

# %%
df_no_outlier = df[df.incomes<=percentile_99]
df_no_outlier
# Out:
#       names  incomes
# 0     mohit     4000
# 1    snehal     5000
# 2    pranav     6000
# 3  pradipta     7000
# 4   bhupesh     7500
# 5       onu     8000

# %%
df.loc[2, 'incomes'] = np.nan
df
# Out:
#       names     incomes
# 0     mohit      4000.0
# 1    snehal      5000.0
# 2    pranav         NaN
# 3  pradipta      7000.0
# 4   bhupesh      7500.0
# 5       onu      8000.0
# 6      elon  10000000.0

# %%
df.incomes.mean()
# Out:
# np.float64(1671916.6666666667)

# %%
df_new = df.fillna(df.incomes.mean())
df_new
# Out:
#       names       incomes
# 0     mohit  4.000000e+03
# 1    snehal  5.000000e+03
# 2    pranav  1.671917e+06
# 3  pradipta  7.000000e+03
# 4   bhupesh  7.500000e+03
# 5       onu  8.000000e+03
# 6      elon  1.000000e+07

# %%
df_new = df.fillna(df.incomes.median())
df_new
# Out:
#       names     incomes
# 0     mohit      4000.0
# 1    snehal      5000.0
# 2    pranav      7250.0
# 3  pradipta      7000.0
# 4   bhupesh      7500.0
# 5       onu      8000.0
# 6      elon  10000000.0
