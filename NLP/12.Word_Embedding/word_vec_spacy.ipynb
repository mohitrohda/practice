# %%
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

doc = nlp("dog cat banana mohit rohda")

for token in doc:
    print(token.text, "Vector:",token.has_vector, "OOV:", token.is_oov)
# Out:
# dog Vector: True OOV: False
# cat Vector: True OOV: False
# banana Vector: True OOV: False
# mohit Vector: True OOV: False
# rohda Vector: False OOV: True

# %%
doc[0].vector.shape
# Out:
# (300,)

# %%
base_token = nlp("bread")
base_token.vector.shape
# Out:
# (300,)

# %%
doc = nlp("bread sandwich burger car tiger human wheat")

for token in doc:
    print(f"{token.text} <-> {base_token.text}:", token.similarity(base_token))
# Out:
# bread <-> bread: 1.0
# sandwich <-> bread: 0.687455952167511
# burger <-> bread: 0.544037401676178
# car <-> bread: 0.16441147029399872
# tiger <-> bread: 0.14492353796958923
# human <-> bread: 0.21103662252426147
# wheat <-> bread: 0.6572456359863281

# %%
def print_similarity(base_word, words_to_compare):
    base_token = nlp(base_word)
    doc = nlp(words_to_compare)
    for token in doc:
        print(f"{token.text} <-> {base_token.text}: ", token.similarity(base_token))

# %%
print_similarity("iphone", "apple samsung iphone dog kitten smartphone")
# Out:
# apple <-> iphone:  0.6339781284332275
# samsung <-> iphone:  0.6678677201271057
# iphone <-> iphone:  0.9999999403953552
# dog <-> iphone:  0.1743103712797165
# kitten <-> iphone:  0.1468581259250641
# smartphone <-> iphone:  0.5473617911338806
